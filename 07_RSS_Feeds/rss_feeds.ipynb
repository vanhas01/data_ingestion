# %% [markdown]
# # Getting Text data from RSS-Feeds

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import feedparser
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Settings
import warnings
warnings.filterwarnings("ignore")

# Current working directory
print(f'Current working directory: {os.getcwd()}')
# Out:
# Current working directory: u:\Lektionen\GitHub_Repositories\data_ingestion\07_RSS_Feeds

# %% [markdown]
# ## Parse the RSS feed

# %%
# RSS feeds from NZZ website
feed = feedparser.parse("https://www.nzz.ch/startseite.rss")
feed

# %% [markdown]
# ## Extract the data

# %%
# Get data from RSS feeds
feed_entries = feed.entries

# Initialize an empty string to store the text
wordcloud_text = ""

# Show first RSS-feeds
print("Article Titles:")
for entry in feed.entries:

    article_title = entry.title
    article_link = entry.link
    article_published_at = entry.published
    article_published_at_parsed = entry.published_parsed

    # Append the title to the wordcloud_text
    wordcloud_text += f"{article_title} "

    # Change and format output
    print(f"{article_title}")
    # print(f"{article_title}[{article_link}]")
    # print(f"Published at {article_published_at}")
# Out:
# Article Titles:
# KOMMENTAR - Bootsunglück im Mittelmeer: Wenn Medien zwanghaft einen Zusammenhang mit dem Klimawandel herstellen, geht die Verhältnismässigkeit unter
# Drei Tote und vier Schwerverletzte bei Messerattacke – Polizei meldet Festnahme, Zusammenhang mit Anschlag noch unklar
# DJ stand während des Anschlags auf der Bühne: «Bitte mach einfach weiter, wir wollen keine Massenpanik»
# KOMMENTAR - Nicht nur in Solingen: Die innere Sicherheit implodiert – Deutschland steht unter mentalem Dauerstress
# Caroline H. gilt als die gefährlichste Frau der Schweiz. Sie sagt: «Ich habe die mir präsentierten Tötungsdelikte zu meinen eigenen gemacht»
# NZZ FORMAT - Der Klimawandel bringt die Alpen zum Bröckeln – unser Dok-Film über die schwindende Stabilität unserer Berge
# INTERVIEW - «Wer mit 50 findet, er sei noch 30, tut mir einfach nur leid», sagt die Philosophin Barbara Bleisch
# Wir sollten auf keinen Fall weitergehen. Auf der anderen Seite hat es vorzügliche Scharfschützen. Unterwegs im Bürgerkriegsland Jemen
# Alain Delon kämpfte in Indochina und wurde zum Weltstar. Hinter dem bildschönen Gesicht verbargen sich Abgründe
# Bitte lasst Belgien nicht verdampfen!
# Die Menopause souverän meistern
# INTERVIEW - «Die Leute haben heute weniger Sex, weil sie weniger Alkohol trinken»
# Ueli, der Staatsfeind
# Online «grosse Schweine schlachten»: In Südostasien boomt ein perfides Geschäft, das Menschen in aller Welt in den Ruin treibt
# Wie sicher ist Afghanistan drei Jahre nach dem Sieg der Taliban? Das hängt von der Perspektive ab
# Michail sollte in Norwegen als Professor José für den Kreml spionieren – doch dann ging alles schief. Die Geschichte eines wahrlich unfähigen Agenten
# Wie Kamala Harris und Donald Trump mit Influencern um die Gunst der jungen Wähler kämpfen
# Robert Kennedy unterstützt Donald Trump: «Die Demokraten sind zur Partei des Krieges, der Zensur, der Korruption und des Grosskapitals geworden»
# OECD-Mindeststeuer: Republikanische Abgeordnete drohen der Schweiz mit Vergeltungsmassnahmen, sollte sie eine «extraterritoriale Steuer» einführen
# GASTKOMMENTAR - Das Regime in Peking kann dem Schrumpfen der Bevölkerung nur noch zusehen, ein Dagegenhalten gibt es nicht mehr
# Terrorverdacht nach Explosion vor Synagoge in Südfrankreich
# Ein Ministerpräsident, ein General und ein geschasster Banker: Steht Libyen erneut vor einem Bürgerkrieg?
# Tote Wagner-Kämpfer im Wüstensand: Stösst Russland in Afrika an seine Grenzen?
# INTERVIEW - Terrorismus in Europa: «Es gibt genügend Hinweise, dass sich etwas Grösseres ankündigt»
# Wie locker sitzen die Atombomben?
# Die Offensive der Ukrainer in Kursk erwischt Weissrusslands Diktator auf dem falschen Fuss
# Russische Schiffe, Militärbasen und Treibstoffdepots in Flammen: Die Ukrainer treffen strategische Ziele auf grosse Distanz
# GASTKOMMENTAR - Zwischen der Verteufelung und der Verklärung des «Wilden» durch den Westen tun sich oft Abgründe auf; vieles bleibt tabu
# GASTKOMMENTAR - Die Schweiz braucht eine Debatte über die Beziehungen zu China
# KOMMENTAR - Die Zukunft der Ukraine hängt in der Schwebe – Zeit, dass die EU aus dem Sommerschlaf erwacht
# AMERIKA ENTSCHEIDET - Parteitage in Chicago: «Die Demokraten haben sich in Rekordzeit neu erfunden»
# Zeit der Abrechnung in Bangladesh: Sheikh Hasina ist nach ihrem Sturz mit Dutzenden von Klagen konfrontiert
# Israels Geheimdienstchef warnt vor «jüdischem Terrorismus» – Ben-Gvir fordert seine Entlassung
# Am Nestlé-Sitz sind die Mitarbeiter über den abrupten CEO-Wechsel nicht erstaunt – bloss über den Zeitpunkt
# Ein Wasserskandal, viele enttäuschte Aktionäre und immer wieder dieser Zucker: Vor diesen Herausforderungen steht der neue Nestlé-Chef
# Fast Food forever? McDonald’s verfolgt in der Schweiz grosse Pläne
# Gold auf Allzeithoch: Während die Schweizer ihre Goldvreneli verscherbeln, kaufen die Chinesen für Milliarden dazu
# US-Notenbankchef Jerome Powell stimmt die Börse auf eine baldige Zinssenkung ein
# Nach jahrelangem Streit: Die Deutsche Bank einigt sich mit einem Teil der Postbank-Kläger und senkt so ihre Rechtsrisiken
# «Richter müssen Gesetze interpretieren, nicht selber welche schaffen»: Bundesrichter kritisiert Klima-Urteil des Gerichtshofs für Menschenrechte gegen die Schweiz scharf
# Sparen als Chance – muss die Entwicklungshilfe effizienter werden?
# Ein aggressiver Hautpilz geht um – Schuld sollen unhygienische Barber-Shops sein
# Albtraum für Eltern: Ein Jugendlicher belästigt an der Zürcher Goldküste Mädchen auf dem Schulweg
# Mehr Solarstrom erzeugen und Energie für den Winter speichern: Der Regierungsrat schlägt eine Pflicht für Photovoltaik auf bestehenden Dächern vor
# Benin-Bronzen sind die umstrittensten Raubgüter der Kolonialzeit. Jetzt stehen sie in zwei Zürcher Museen – vielleicht zum letzten Mal
# Verstappens One-Man-Show ist vorbei – warum Red Bull die Vormachtstellung in der Formel 1 verliert
# Für den Lieblingsspieler macht Guardiola eine Ausnahme – Ilkay Gündogan kehrt zu Manchester City zurück
# Er trotzt auf seinen Abenteuern wilden Hunden und der Müdigkeit – Robin Gemperle wird mit zehn Jahren Verspätung doch noch Radprofi
# In Bangladesh üben Muslime nach ihrer erfolgreichen Revolte Vergeltung an den Hindus
# GASTKOMMENTAR - Ein belgischer Kolumnist imaginiert die wahllose Ermordung von Juden – der Tabubruch ist zur Norm geworden
# Philosophie wird mit dem Tod bestraft: Die Verteidigungsrede des Sokrates ist ein Manifest für die Freiheit des Denkens
# Dehnt sich das Universum schneller aus, als es sollte? Die Astronomin Wendy Freedman meldet Zweifel an
# Der Fall des Tennisspielers Jannik Sinner: War es Doping oder Kontamination durch Massage? Was die Laborwerte aussagen
# Laut einem Extremszenario könnten die Gletscher der Antarktis in Zukunft schnell kollabieren. Jetzt zeigt eine Studie: Sie sind doch stabiler

# %% [markdown]
# ## Generate a WordCloud

# %%
# Generate the word cloud
wordcloud = WordCloud(width=800, 
                      height=400, 
                      background_color='black').generate(wordcloud_text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide the axes
plt.show()

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2024-08-24 17:33:37
# Python Version: 3.11.9
# -----------------------------------
